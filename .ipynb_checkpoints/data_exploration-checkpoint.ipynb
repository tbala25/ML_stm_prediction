# %%
#######################################
########## IMPORTS ####################
from localLibrary_AWSConnector import *
import pandas as pd

# %%
#HELPER FUNCTIONS
def get_data_s3():
    data_list = []
    data_dict = {}

    # Iterate through all buckets
    for bucket in s3.buckets.all():
        # Iterate through all items
        for obj in s3.Bucket(bucket.name).objects.all():
            if('data/' in obj.key and obj.key != 'data/'):
                data_list.append(obj.key)
                
                # Save STM files as DataFrames
                if('STM' in obj.key and 'non' not in obj.key): 
                    objct = s3.Bucket(bucket.name).Object(obj.key).get()
                    data_dict[obj.key] = pd.read_csv(objct['Body'], index_col=0)

    print(data_list)
    
    return data_dict

def convert_time_to_int(time):
    #print(time)
    if time != time:
        return None
    else:
        return int(''.join(c for c in time if c.isdigit()))

# %%
all_data = get_data_s3()
# Out:
# ['data/CRM_STM.csv', 'data/CRM_lost.csv', 'data/CRM_nonSTM.csv', 'data/FTS_STM.csv', 'data/FTS_lost.csv', 'data/FTS_nonSTM.csv', 'data/MK_STM.csv', 'data/MK_lost.csv', 'data/MK_nonSTM.csv', 'data/SG_STM.csv', 'data/SG_lost.csv', 'data/SG_nonSTM.csv', 'data/YZ_STM.csv', 'data/YZ_lost.csv', 'data/YZ_nonSTM.csv']

# %%
all_data.keys()
# Out:
# dict_keys(['data/CRM_STM.csv', 'data/FTS_STM.csv', 'data/MK_STM.csv', 'data/SG_STM.csv', 'data/YZ_STM.csv'])

# %%
for key in all_data.keys():
    print(key)
    print(all_data[key].describe(include='all'))
    print("=====================================================")
# Out:
# data/CRM_STM.csv
#         TotalCRMActivityVolume          EarliestCRM            LatestCRM
# count              3149.000000                 3149                 3149
# unique                     NaN                 2016                 3107
# top                        NaN  2009-05-21 01:29:13  2009-05-21 01:29:13
# freq                       NaN                  916                   25
# mean                 12.091458                  NaN                  NaN
# std                  10.898481                  NaN                  NaN
# min                   1.000000                  NaN                  NaN
# 25%                   3.000000                  NaN                  NaN
# 50%                   8.000000                  NaN                  NaN
# 75%                  20.000000                  NaN                  NaN
# max                  94.000000                  NaN                  NaN
# =====================================================
# data/FTS_STM.csv
#         TotalFanaticsTransactions  TotalFanaticsProductQty  \
# count                  172.000000               172.000000
# unique                        NaN                      NaN
# top                           NaN                      NaN
# freq                          NaN                      NaN
# mean                     2.866279                 3.017442
# std                      2.371769                 2.636837
# min                      1.000000                 1.000000
# 25%                      1.000000                 1.000000
# 50%                      2.000000                 2.000000
# 75%                      4.000000                 4.000000
# max                     15.000000                17.000000
#
#         TotalFanaticsDollarValue EarliestFanaticsDate LatestFanaticsDate
# count                 172.000000                  172                172
# unique                       NaN                  129                133
# top                          NaN           2017-11-27         2018-11-09
# freq                         NaN                    6                  5
# mean                  102.882616                  NaN                NaN
# std                    88.342622                  NaN                NaN
# min                     5.690000                  NaN                NaN
# 25%                    43.727500                  NaN                NaN
# 50%                    75.625000                  NaN                NaN
# 75%                   140.480000                  NaN                NaN
# max                   634.890000                  NaN                NaN
# =====================================================
# data/MK_STM.csv
#         TotalMarketoVolume  EarliestMarketoDate    LatestMarketoDate
# count          2978.000000                 2978                 2978
# unique                 NaN                 2867                 2973
# top                    NaN  2015-11-04 23:16:08  2017-09-29 17:04:48
# freq                   NaN                    8                    3
# mean             79.479516                  NaN                  NaN
# std              87.876997                  NaN                  NaN
# min               1.000000                  NaN                  NaN
# 25%              15.000000                  NaN                  NaN
# 50%              47.000000                  NaN                  NaN
# 75%             121.000000                  NaN                  NaN
# max            1697.000000                  NaN                  NaN
# =====================================================
# data/SG_STM.csv
#        cjsgActivityType cjsgSecondaryTicketType  TotalSeatGeekTransactions  \
# count              2230                    2230                2230.000000
# unique                2                       3                        NaN
# top            Purchase                 Primary                        NaN
# freq               2103                    1823                        NaN
# mean                NaN                     NaN                   4.432287
# std                 NaN                     NaN                  10.352844
# min                 NaN                     NaN                   1.000000
# 25%                 NaN                     NaN                   1.000000
# 50%                 NaN                     NaN                   1.000000
# 75%                 NaN                     NaN                   2.000000
# max                 NaN                     NaN                 122.000000
#
#         TotalTicketVolume  TotalScannedTicketVolume  TotalTicketDollarValue  \
# count         2230.000000               2230.000000             2230.000000
# unique                NaN                       NaN                     NaN
# top                   NaN                       NaN                     NaN
# freq                  NaN                       NaN                     NaN
# mean             9.057848                  2.833632              360.323318
# std             25.837150                 11.692932             2332.295048
# min              1.000000                  0.000000                0.000000
# 25%              2.000000                  0.000000                0.000000
# 50%              2.000000                  0.000000                0.000000
# 75%              4.000000                  0.000000               10.000000
# max            431.000000                296.000000            61115.000000
#
#            EarliestSeatGeekDate       LatestSeatGeekDate
# count                      2230                     2230
# unique                     2230                     2230
# top     2018-02-15 16:43:59.027  2018-02-15 16:43:59.027
# freq                          1                        1
# mean                        NaN                      NaN
# std                         NaN                      NaN
# min                         NaN                      NaN
# 25%                         NaN                      NaN
# 50%                         NaN                      NaN
# 75%                         NaN                      NaN
# max                         NaN                      NaN
# =====================================================
# data/YZ_STM.csv
#         TotalYinzcamVolume  EarliestYinzcamDate    LatestYinzcamDate
# count            68.000000                   68                   68
# unique                 NaN                   68                   68
# top                    NaN  2017-01-29 19:00:11  2017-02-24 20:31:29
# freq                   NaN                    1                    1
# mean             58.029412                  NaN                  NaN
# std              71.293794                  NaN                  NaN
# min               2.000000                  NaN                  NaN
# 25%              12.000000                  NaN                  NaN
# 50%              25.500000                  NaN                  NaN
# 75%              70.500000                  NaN                  NaN
# max             313.000000                  NaN                  NaN
# =====================================================

# %%
STM = None
for key in all_data.keys():
    if STM is None:
        STM = all_data[key]
    else:
        STM = STM.merge(all_data[key], how = 'outer', on = 'SSB_CRMSYSTEM_CONTACT_ID')

# %%
STM.describe(include='all')
# Out:
#         TotalCRMActivityVolume          EarliestCRM            LatestCRM  \
# count              3408.000000                 3408                 3408
# unique                     NaN                 2016                 3107
# top                        NaN  2009-05-21 01:29:13  2009-05-21 01:29:13
# freq                       NaN                  952                   25
# mean                 11.736796                  NaN                  NaN
# std                  10.708438                  NaN                  NaN
# min                   1.000000                  NaN                  NaN
# 25%                   3.000000                  NaN                  NaN
# 50%                   8.000000                  NaN                  NaN
# 75%                  19.000000                  NaN                  NaN
# max                  94.000000                  NaN                  NaN
#
#         TotalFanaticsTransactions  TotalFanaticsProductQty  \
# count                  211.000000               211.000000
# unique                        NaN                      NaN
# top                           NaN                      NaN
# freq                          NaN                      NaN
# mean                     3.071090                 3.227488
# std                      2.620372                 2.925325
# min                      1.000000                 1.000000
# 25%                      1.000000                 1.000000
# 50%                      2.000000                 2.000000
# 75%                      4.000000                 4.000000
# max                     15.000000                17.000000
#
#         TotalFanaticsDollarValue EarliestFanaticsDate LatestFanaticsDate  \
# count                 211.000000                  211                211
# unique                       NaN                  129                133
# top                          NaN           2017-09-29         2018-11-09
# freq                         NaN                    7                  8
# mean                  111.873223                  NaN                NaN
# std                    97.435255                  NaN                NaN
# min                     5.690000                  NaN                NaN
# 25%                    48.730000                  NaN                NaN
# 50%                    86.760000                  NaN                NaN
# 75%                   149.480000                  NaN                NaN
# max                   634.890000                  NaN                NaN
#
#         TotalMarketoVolume  EarliestMarketoDate  ... cjsgSecondaryTicketType  \
# count          3227.000000                 3227  ...                    2230
# unique                 NaN                 2867  ...                       3
# top                    NaN  2015-11-04 23:16:06  ...                 Primary
# freq                   NaN                    8  ...                    1823
# mean             81.492718                  NaN  ...                     NaN
# std              89.028581                  NaN  ...                     NaN
# min               1.000000                  NaN  ...                     NaN
# 25%              16.000000                  NaN  ...                     NaN
# 50%              48.000000                  NaN  ...                     NaN
# 75%             123.500000                  NaN  ...                     NaN
# max            1697.000000                  NaN  ...                     NaN
#
#        TotalSeatGeekTransactions TotalTicketVolume  TotalScannedTicketVolume  \
# count                2230.000000       2230.000000               2230.000000
# unique                       NaN               NaN                       NaN
# top                          NaN               NaN                       NaN
# freq                         NaN               NaN                       NaN
# mean                    4.432287          9.057848                  2.833632
# std                    10.352844         25.837150                 11.692932
# min                     1.000000          1.000000                  0.000000
# 25%                     1.000000          2.000000                  0.000000
# 50%                     1.000000          2.000000                  0.000000
# 75%                     2.000000          4.000000                  0.000000
# max                   122.000000        431.000000                296.000000
#
#         TotalTicketDollarValue     EarliestSeatGeekDate  \
# count              2230.000000                     2230
# unique                     NaN                     2230
# top                        NaN  2018-02-15 16:43:59.027
# freq                       NaN                        1
# mean                360.323318                      NaN
# std                2332.295048                      NaN
# min                   0.000000                      NaN
# 25%                   0.000000                      NaN
# 50%                   0.000000                      NaN
# 75%                  10.000000                      NaN
# max               61115.000000                      NaN
#
#              LatestSeatGeekDate TotalYinzcamVolume  EarliestYinzcamDate  \
# count                      2230          78.000000                   78
# unique                     2230                NaN                   68
# top     2018-02-15 16:43:59.027                NaN  2017-02-22 18:07:05
# freq                          1                NaN                    4
# mean                        NaN          55.320513                  NaN
# std                         NaN          67.297651                  NaN
# min                         NaN           2.000000                  NaN
# 25%                         NaN          12.750000                  NaN
# 50%                         NaN          28.000000                  NaN
# 75%                         NaN          69.000000                  NaN
# max                         NaN         313.000000                  NaN
#
#           LatestYinzcamDate
# count                    78
# unique                   68
# top     2017-03-01 01:57:19
# freq                      4
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
# [11 rows x 22 columns]

# %%
pd.DataFrame(STM.isna().sum()/len(STM), columns = ['Pct_Null']).sort_values('Pct_Null', ascending= True)
# Out:
#                            Pct_Null
# TotalCRMActivityVolume     0.084855
# EarliestCRM                0.084855
# LatestCRM                  0.084855
# EarliestMarketoDate        0.133459
# TotalMarketoVolume         0.133459
# LatestMarketoDate          0.133459
# cjsgActivityType           0.401182
# cjsgSecondaryTicketType    0.401182
# TotalSeatGeekTransactions  0.401182
# TotalTicketVolume          0.401182
# TotalScannedTicketVolume   0.401182
# TotalTicketDollarValue     0.401182
# EarliestSeatGeekDate       0.401182
# LatestSeatGeekDate         0.401182
# EarliestFanaticsDate       0.943340
# LatestFanaticsDate         0.943340
# TotalFanaticsProductQty    0.943340
# TotalFanaticsTransactions  0.943340
# TotalFanaticsDollarValue   0.943340
# EarliestYinzcamDate        0.979055
# TotalYinzcamVolume         0.979055
# LatestYinzcamDate          0.979055

# %%
ax = STM.hist(bins=30, grid=False, figsize=(15,10), color='#86bf91', zorder=2, rwidth=0.9)

# %%
STM['EarliestCRM_int'] = [convert_time_to_int(x) for x in STM['EarliestCRM']]
STM['LatestCRM_int'] = [convert_time_to_int(x) for x in STM['LatestCRM']]

STM['LatestSeatGeek_int'] = [convert_time_to_int(x) for x in STM['LatestSeatGeekDate']]
STM['EarliestSeatGeek_int'] = [convert_time_to_int(x) for x in STM['EarliestSeatGeekDate']]

STM['EarliestMarketo_int'] = [convert_time_to_int(x) for x in STM['EarliestMarketoDate']]
STM['LatestMarketo_int'] = [convert_time_to_int(x) for x in STM['LatestMarketoDate']]

STM['EarliestFanatics_int'] = [convert_time_to_int(x) for x in STM['EarliestFanaticsDate']]
STM['LatestFanatics_int'] = [convert_time_to_int(x) for x in STM['LatestFanaticsDate']]

STM['EarliestYinzcam_int'] = [convert_time_to_int(x) for x in STM['EarliestYinzcamDate']]
STM['LatestYinzcam_int'] = [convert_time_to_int(x) for x in STM['LatestYinzcamDate']]

# %%
ax = STM.hist(bins=30, grid=False, figsize=(15,10), color='#86bf91', zorder=2, rwidth=0.9)
